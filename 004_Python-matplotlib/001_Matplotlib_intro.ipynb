# %%
import matplotlib.pyplot as plt
import numpy as np

# x points (x_p) and y points (y_p) for co-ordinates
x_p = np.array([0, 10])
y_p = np.array([0, 20])
plt.plot(x_p, y_p)
plt.show()

# %% [markdown]
# #### Matplotlib Intro ####
